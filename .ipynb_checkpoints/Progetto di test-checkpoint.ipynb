# %%
print('SLEEP DIARY')
# Out:
# SLEEP DIARY

# %%
print('Inserire il nome del file excel contenente i dati:')
n=input()
# Out:
# Inserire il nome del file excel contenente i dati:
# Sleep dataset 2020.xlsx

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from datetime import datetime
dati=pd.read_excel(n)
dati.drop(0,inplace=True)
dati.head()
# Out:
#                   Data  \
# 1  2020-01-01 00:00:00
# 2  2020-01-02 00:00:00
# 3  2020-01-03 00:00:00
# 4  2020-01-04 00:00:00
# 5  2020-01-05 00:00:00
#
#    Ieri ha fatto un sonnellino di durata (minuti totali)?  \
# 1                                                 90
# 2                                                  0
# 3                                                  0
# 4                                                  0
# 5                                                  0
#
#   A che ora è andato a letto ieri sera?  \
# 1                              01:05:00
# 2                              23:02:00
# 3                              00:28:00
# 4                              22:55:00
# 5                              23:00:00
#
#   A che ora ha spento la luce per dormire?  \
# 1                                 01:08:00
# 2                                 23:51:00
# 3                                 00:45:00
# 4                                 00:03:00
# 5                                 23:29:00
#
#    Dallo spegnimento della luce, in quanto tempo si è addormentato?  \
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                 10
# 5                                                  4
#
#   Orario previsto del risveglio questa mattina?  \
# 1                                      08:30:00
# 2                                      07:30:00
# 3                                      07:00:00
# 4                                      06:00:00
# 5                                      07:00:00
#
#   Qual è stato l'orario del risveglio finale questa mattina?  \
# 1                                           08:12:00
# 2                                           07:30:00
# 3                                           07:50:00
# 4                                           06:00:00
# 5                                           07:00:00
#
#   A che ora si è alzato dal letto?  \
# 1                         08:12:00
# 2                         07:30:00
# 3                         07:55:00
# 4                         06:00:00
# 5                         07:00:00
#
#    Quante volte si è svegliato/a durante la notte? (0 se non si è svegliato/a)  \
# 1                                                  4
# 2                                                  0
# 3                                                  2
# 4                                                  0
# 5                                                  3
#
#    Quanti minuti in totale è rimasto/a sveglio/a nel corso della notte?  \
# 1                                                 20
# 2                                                  0
# 3                                                  2
# 4                                                  0
# 5                                                 15
#
#    Quanto è stato disturbato il suo sonno la notte scorsa? (1=per niente, 10=moltissimo)  \
# 1                                                  6
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  5
#
#    Qualità del sonno la scorsa notte (1=molto scarso, 10=molto buono)  \
# 1                                                  5
# 2                                                  7
# 3                                                  7
# 4                                                  7
# 5                                                  5
#
#    Livello di affaticamento di ieri (1=niente, 10=estremamente stancante)  \
# 1                                                  4
# 2                                                  2
# 3                                                  3
# 4                                                  6
# 5                                                  6
#
#    Livello di sonnolenza di ieri (1=per niente, 10=estremamente sonnolento)  \
# 1                                                  2
# 2                                                  1
# 3                                                  2
# 4                                                  1
# 5                                                  3
#
#    (polar)\nDaily activity goal  (polar)\nActual sleep  \
# 1                          0.73                   0.90
# 2                          0.90                   0.96
# 3                          0.81                   0.93
# 4                          1.99                   0.93
# 5                          0.96                   0.93
#
#    (polar)\nSleep continuity
# 1                        1.6
# 2                        4.8
# 3                        2.7
# 4                        2.8
# 5                        2.6

# %%
x=np.arange(0,dati.shape[0],1)
t_w=np.array(dati.iloc[:,8])
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(x,t_w,color='firebrick')
plt.title("Quante volte si è svegliato nella notte durante l'anno",fontsize=25)
plt.xlabel('Giorno',fontsize=20)
# Out:
# Text(0.5, 0, 'Giorno')

# %%
d_s=np.array(dati.iloc[:,10])
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(x,d_s,color='lightcoral')
plt.title("Quanto è stato disturbato il sonno durante l'anno",fontsize=25)
plt.xlabel('Giorno',fontsize=20)
# Out:
# Text(0.5, 0, 'Giorno')

# %%
q_s=np.array(dati.iloc[:,11])
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(x,q_s,color='coral')
plt.title("Qualità del sonno durante l'anno",fontsize=25)
plt.xlabel('Giorno',fontsize=20)
# Out:
# Text(0.5, 0, 'Giorno')

# %%
a=np.array(dati.iloc[:,12])
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(x,a,color='mediumpurple')
plt.title("Livello di affaticamento durante l'anno",fontsize=25)
plt.xlabel('Giorno',fontsize=20)
# Out:
# Text(0.5, 0, 'Giorno')

# %%
sonnolenza=np.array(dati.iloc[:,13])
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(x,sonnolenza,color='m')
plt.title("Livello di sonnolenza durante l'anno",fontsize=25)
plt.xlabel('Giorno',fontsize=20)
# Out:
# Text(0.5, 0, 'Giorno')

# %%
min_addormentamento=np.array(dati.iloc[:,4])
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(x,min_addormentamento,color='navy')
plt.axhline(y=30, color='red')
plt.axhline(y=5, color='red')
plt.title("Minuti impiegati per addormentarsi durante l'anno",fontsize=25)
plt.xlabel('Giorno',fontsize=20)
# Out:
# Text(0.5, 0, 'Giorno')
